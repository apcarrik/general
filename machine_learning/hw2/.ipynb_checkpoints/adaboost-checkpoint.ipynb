# %% [markdown]
# # Boosting a decision stump
#
# The goal of this notebook is to implement your own boosting module.
#
# * Go through an implementation of decision trees.
# * Implement Adaboost ensembling.
# * Use your implementation of Adaboost to train a boosted decision stump ensemble.
# * Evaluate the effect of boosting (adding more decision stumps) on performance of the model.
# * Explore the robustness of Adaboost to overfitting.
#
# *This file is adapted from course material by Carlos Guestrin and Emily Fox.*
#
# Let's get started!

# %%
import sys
# !conda install --yes --prefix {sys.prefix} pandas
# !conda install --yes --prefix {sys.prefix} numpy
# !conda install --yes --prefix {sys.prefix} scikit-learn
# !conda install --yes --prefix {sys.prefix} graphviz
# !conda install --yes --prefix {sys.prefix} dl8.5
# !conda install --yes --prefix {sys.prefix} chefboost
# !conda install --yes --prefix {sys.prefix} libsvm
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/adamcarriker/opt/anaconda3/envs/MachineLearning
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     joblib-1.0.1               |     pyhd3eb1b0_0         208 KB
#     llvm-openmp-12.0.0         |       h0dcd299_1         262 KB
#     scikit-learn-0.24.2        |   py39hb2f4e1b_0         5.0 MB
#     scipy-1.7.1                |   py39h88652d9_2        15.6 MB
#     threadpoolctl-2.2.0        |     pyh0d69192_0          16 KB
#     ------------------------------------------------------------
#                                            Total:        21.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             pkgs/main/noarch::joblib-1.0.1-pyhd3eb1b0_0
#   libgfortran        pkgs/main/osx-64::libgfortran-3.0.1-h93005f0_2
#   llvm-openmp        pkgs/main/osx-64::llvm-openmp-12.0.0-h0dcd299_1
#   scikit-learn       pkgs/main/osx-64::scikit-learn-0.24.2-py39hb2f4e1b_0
#   scipy              pkgs/main/osx-64::scipy-1.7.1-py39h88652d9_2
#   threadpoolctl      pkgs/main/noarch::threadpoolctl-2.2.0-pyh0d69192_0
#
#
#
# Downloading and Extracting Packages
# joblib-1.0.1         | 208 KB    | ##################################### | 100%
# threadpoolctl-2.2.0  | 16 KB     | ##################################### | 100%
# scikit-learn-0.24.2  | 5.0 MB    | ##################################### | 100%
# llvm-openmp-12.0.0   | 262 KB    | ##################################### | 100%
# scipy-1.7.1          | 15.6 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: -
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                               \failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - backcall -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0']
#   - backports -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0|>=3.6,<3.7.0a0']
#   - ipython_genutils -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - olefile -> python[version='>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0']
#   - pexpect -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.5,<3.6.0a0']
#   - ptyprocess -> python[version='>=2.7,<2.8.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0']
#   - pycparser -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.5,<3.6.0a0|>=3.7,<3.8.0a0']
#   - pyparsing -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#   - wcwidth -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.8,<3.9.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']
#
# Your python: python=3.9
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package intel-openmp conflicts for:
# numpy -> mkl[version='>=2021.3.0,<2022.0a0'] -> intel-openmp=2021
# scipy -> mkl[version='>=2021.3.0,<2022.0a0'] -> intel-openmp=2021
# mkl_random -> mkl[version='>=2021.2.0,<2022.0a0'] -> intel-openmp=2021
# mkl-service -> mkl[version='>=2021.2.0,<2022.0a0'] -> intel-openmp=2021
# mkl -> intel-openmp=2021
# scikit-learn -> mkl[version='>=2019.4,<2020.0a0'] -> intel-openmp
# mkl_fft -> mkl[version='>=2021.2.0,<2022.0a0'] -> intel-openmp=2021
# numexpr -> mkl[version='>=2021.2.0,<2022.0a0'] -> intel-openmp=2021
# numpy-base -> mkl[version='>=2021.3.0,<2022.0a0'] -> intel-openmp=2021
#
# Package pygments conflicts for:
# notebook -> nbconvert -> pygments[version='>=2.4.1']
# nbconvert -> jupyterlab_pygments -> pygments[version='>=2.4.1,<3']
# jupyterlab_pygments -> pygments[version='>=2.4.1,<3']
# jupyter_server -> nbconvert -> pygments[version='>=2.4.1']
# jupyterlab -> ipython -> pygments
# ipython -> pygments
# nbconvert -> pygments[version='>=2.4.1']
# ipykernel -> ipython[version='>=7.23.1,<8.0'] -> pygments
# prompt-toolkit -> pygments
#
# Package tk conflicts for:
# pillow -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# kiwisolver -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backports -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python_abi -> python=3.9 -> tk[version='>=8.6.10,<8.7.0a0']
# fonttools -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# nbclient -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# entrypoints -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# scipy -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# nest-asyncio -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pandocfilters -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# pip -> python[version='>=3.10,<3.11.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# urllib3 -> python[version='>=3.6,<4.0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# debugpy -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# pickleshare -> python[version='>=3'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mkl_fft -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# traitlets -> python[version='>=3.7'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# nbclassic -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backports.functools_lru_cache -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# tornado -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# async_generator -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# notebook -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# pyrsistent -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# terminado -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# wcwidth -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jupyter_core -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# setuptools -> python[version='>=3.10,<3.11.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.7,<8.7.0a0']
# certifi -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# websocket-client -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# jupyterlab -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# decorator -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# cffi -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# pysocks -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# cryptography -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# testpath -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# packaging -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python-dateutil -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyopenssl -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ipython_genutils -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jinja2 -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jupyter_server -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# jupyterlab_pygments -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# prompt-toolkit -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# prometheus_client -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# cycler -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# pycparser -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# brotlipy -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# matplotlib-inline -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# nbconvert -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jupyter_client -> python[version='>=3.6.1'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# json5 -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# argon2-cffi -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# pygments -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# babel -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# anyio -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# munkres -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# sniffio -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# numpy -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mkl_random -> python[version='>=3.7,<3.8.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# mistune -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# ipython -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# send2trash -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# threadpoolctl -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyparsing -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pytz -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# numpy-base -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# zipp -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# python=3.9 -> tk[version='>=8.6.10,<8.7.0a0']
# wheel -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# charset-normalizer -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# scikit-learn -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# olefile -> python[version='>=3.5,<3.6.0a0'] -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.11,<8.7.0a0']
# jsonschema -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pillow -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.11,<8.7.0a0']
# importlib-metadata -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# webencodings -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# jupyterlab_server -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# defusedxml -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# mkl-service -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# numexpr -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# idna -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# bottleneck -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# jedi -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# nbformat -> python[version='>=3.5'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# requests -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# appnope -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# chardet -> python[version='>=3.6,<3.7.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# joblib -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# parso -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# six -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# bleach -> python[version='>=3.6'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pyzmq -> python[version='>=3.9,<3.10.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0|>=8.6.11,<8.7.0a0']
# ptyprocess -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# attrs -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# backcall -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# requests-unixsocket -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# pexpect -> python -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# matplotlib -> python[version='>=3.8,<3.9.0a0'] -> tk[version='8.6.*|>=8.6.10,<8.7.0a0|>=8.6.11,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
#
# Package openssl conflicts for:
# brotlipy -> python[version='>=3.6,<3.7.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1k,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a']
# packaging -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# jupyter_server -> python[version='>=3.6,<3.7.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1k,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a']
# fonttools -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# jinja2 -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# pickleshare -> python[version='>=3'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# prometheus_client -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# pip -> python[version='>=3.10,<3.11.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# python=3.9 -> openssl[version='>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a']
# pandas -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# jupyter_core -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2p,<1.0.3a']
# backports.functools_lru_cache -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# pexpect -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# pygments -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# ipython -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# chardet -> python[version='>=3.6,<3.7.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1l,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# pandocfilters -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# websocket-client -> python[version='>=3.6,<3.7.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1k,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a']
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# matplotlib-base -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a']
# parso -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# nbconvert -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# decorator -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# babel -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# pyopenssl -> cryptography[version='>=2.8'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# threadpoolctl -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# python_abi -> python=3.9 -> openssl[version='>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a']
# attrs -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# pyrsistent -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a']
# argon2-cffi -> python[version='>=3.6,<3.7.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1l,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a']
# importlib-metadata -> python[version='>=3.6,<3.7.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1l,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# prompt-toolkit -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# joblib -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# send2trash -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# jedi -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# mistune -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# idna -> python[version='>=3.5'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# ipython_genutils -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# async_generator -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2p,<1.0.3a']
# nbformat -> python[version='>=3.5'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# pyzmq -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# jupyter_client -> python[version='>=3.6.1'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# terminado -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# debugpy -> python[version='>=3.7,<3.8.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a']
# jsonschema -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# kiwisolver -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# jupyterlab -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# zipp -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# mkl_fft -> python[version='>=3.6,<3.7.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1l,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# charset-normalizer -> python[version='>=3.5'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# numpy -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# urllib3 -> cryptography[version='>=1.3.4'] -> openssl[version='1.0.*|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2n,<1.0.3a|>=1.0.2m,<1.0.3a|>=1.1.1e,<1.1.2a|>=1.0.2l,<1.0.3a']
# requests-unixsocket -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# nbclient -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a']
# numexpr -> python[version='>=3.6,<3.7.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1k,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2p,<1.0.3a']
# testpath -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# pysocks -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# jupyterlab_server -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# wcwidth -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# cycler -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# certifi -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# numpy-base -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# pytz -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# mkl-service -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# matplotlib -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# matplotlib-inline -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a']
# pillow -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# scipy -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# scikit-learn -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# anyio -> python[version='>=3.8,<3.9.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a']
# tornado -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# backports -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# bottleneck -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1b,<1.1.2a|>=1.0.2p,<1.0.3a']
# entrypoints -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# nest-asyncio -> python[version='>=3.5'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# appnope -> python[version='>=3.6,<3.7.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1k,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2p,<1.0.3a']
# requests -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# sniffio -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a']
# setuptools -> python[version='>=3.10,<3.11.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# traitlets -> python[version='>=3.7'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# webencodings -> python[version='>=3.9,<3.10.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1b,<1.1.2a']
# jupyterlab_pygments -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# json5 -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# six -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# cffi -> python[version='>=3.6,<3.7.0a0'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.1.1k,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2p,<1.0.3a']
# bleach -> python[version='>=3.6'] -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# ptyprocess -> python -> openssl[version='1.0.*|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1l,<1.1.2a|>=1.0.2l,<1.0.3a|>=1.0.2p,<1.0.3a']
# ...
# requests -> urllib3[version='>=1.21.1,<1.23|>=1.21.1,<1.24|>=1.21.1,<1.25|>=1.21.1,<1.26,!=1.25.0,!=1.25.1|>=1.21.1,<1.27']
# requests-unixsocket -> urllib3[version='>=1.8,<2']
# jupyterlab_server -> requests -> urllib3[version='>=1.21.1,<1.23|>=1.21.1,<1.24|>=1.21.1,<1.25|>=1.21.1,<1.26,!=1.25.0,!=1.25.1|>=1.21.1,<1.27']
#
# Package jupyter_core conflicts for:
# jupyter_server -> nbconvert -> jupyter_core
# nbclassic -> jupyter_server[version='>=1.0.1,<2.0.0'] -> jupyter_core[version='>=4.4.0|>=4.6.0|>=4.6.1']
# jupyter_client -> jupyter_core[version='>=4.6.0']
# nbconvert -> jupyter_core
# jupyterlab_server -> jupyter_server[version='>=1.4,<2'] -> jupyter_core[version='>=4.4.0|>=4.6.0|>=4.6.1']
# nbconvert -> jupyter_client[version='>=4.2'] -> jupyter_core[version='>=4.6.0']
# nbclient -> jupyter_client[version='>=6.1.5'] -> jupyter_core[version='>=4.6.0']
# jupyterlab -> jupyter_server[version='>=1.4,<2'] -> jupyter_core[version='>=4.4.0|>=4.6.0|>=4.6.1']
# ipykernel -> jupyter_client[version='<8.0'] -> jupyter_core[version='>=4.6.0']
# notebook -> jupyter_core[version='>=4.4.0|>=4.6.0|>=4.6.1']
# jupyter_server -> jupyter_core[version='>=4.4.0|>=4.6.0']
# nbformat -> jupyter_core
# jupyterlab -> jupyter_core
#
# Package pandoc conflicts for:
# jupyter_server -> nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# notebook -> nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
#
# Package importlib_metadata conflicts for:
# ipykernel -> argcomplete[version='>=1.12.3'] -> importlib_metadata[version='>=0.23,<5']
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> importlib_metadata
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> importlib_metadata
# jsonschema -> importlib_metadata
#
# Package prompt-toolkit conflicts for:
# ipykernel -> ipython[version='>=7.23.1,<8.0'] -> prompt-toolkit[version='!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0|>=2.0.0,!=3.0.0,!=3.0.1,<3.1.0']
# ipython -> prompt_toolkit[version='>=2.0.0,<4,!=3.0.0,!=3.0.1'] -> prompt-toolkit[version='>=3.0.17,<3.0.18.0a0|>=3.0.20,<3.0.21.0a0|>=3.0.8,<3.0.9.0a0|>=3.0.7,<3.0.8.0a0|>=3.0.6,<3.0.7.0a0|>=3.0.5,<3.0.6.0a0|>=3.0.4,<3.0.5.0a0']
# ipython -> prompt-toolkit[version='!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0|>=2.0.0,!=3.0.0,!=3.0.1,<3.1.0']
# jupyterlab -> ipython -> prompt-toolkit[version='!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0|>=2.0.0,!=3.0.0,!=3.0.1,<3.1.0']
#
# Package libwebp conflicts for:
# matplotlib-base -> pillow[version='>=6.2.0'] -> libwebp[version='>=0.3.0|>=1.2.0,<1.3.0a0']
# pillow -> libwebp[version='>=0.3.0|>=1.2.0,<1.3.0a0']
#
# Package zeromq conflicts for:
# pyzmq -> zeromq[version='4.2.*|>=4.2.3,<4.3|>=4.2.5,<4.2.6.0a0|>=4.3.1,<4.4.0a0|>=4.3.2,<4.4.0a0|>=4.3.3,<4.4.0a0|>=4.3.4,<4.4.0a0']
# jupyter_client -> pyzmq[version='>=13'] -> zeromq[version='4.2.*|>=4.2.3,<4.3|>=4.2.5,<4.2.6.0a0|>=4.3.1,<4.4.0a0|>=4.3.2,<4.4.0a0|>=4.3.3,<4.4.0a0|>=4.3.4,<4.4.0a0']
# jupyter_server -> pyzmq[version='>=17'] -> zeromq[version='>=4.2.3,<4.3|>=4.2.5,<4.2.6.0a0|>=4.3.1,<4.4.0a0|>=4.3.2,<4.4.0a0|>=4.3.3,<4.4.0a0|>=4.3.4,<4.4.0a0']
# notebook -> pyzmq[version='>=17'] -> zeromq[version='4.2.*|>=4.2.3,<4.3|>=4.2.5,<4.2.6.0a0|>=4.3.1,<4.4.0a0|>=4.3.2,<4.4.0a0|>=4.3.3,<4.4.0a0|>=4.3.4,<4.4.0a0']
#
# Package packaging conflicts for:
# nbconvert -> bleach -> packaging
# jupyterlab_server -> packaging
# bleach -> packaging
# jupyterlab -> packaging
#
# Package json5 conflicts for:
# jupyterlab_server -> json5
# jupyterlab -> jupyterlab_server[version='>=2.3,<3'] -> json5
#
# Package zstd conflicts for:
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> zstd[version='>=1.3.7,<1.3.8.0a0|>=1.4.4,<1.5.0a0|>=1.4|>=1.4.5,<1.5.0a0']
# graphviz -> libtiff[version='>=4.0.9,<5.0a0'] -> zstd[version='>=1.3.7,<1.3.8.0a0|>=1.4.4,<1.5.0a0|>=1.4|>=1.4.5,<1.5.0a0']
# libtiff -> zstd[version='>=1.3.7,<1.3.8.0a0|>=1.4.4,<1.5.0a0|>=1.4|>=1.4.5,<1.5.0a0']
# openjpeg -> libtiff[version='>=4.1.0,<5.0a0'] -> zstd[version='>=1.3.7,<1.3.8.0a0|>=1.4.4,<1.5.0a0|>=1.4|>=1.4.5,<1.5.0a0']
# pillow -> libtiff[version='>=4.1.0,<5.0a0'] -> zstd[version='>=1.3.7,<1.3.8.0a0|>=1.4.4,<1.5.0a0|>=1.4|>=1.4.5,<1.5.0a0']
#
# Package parso conflicts for:
# jedi -> parso[version='0.1.0|>=0.1.0,<0.2|>=0.2.0|>=0.3.0|>=0.5.0|>=0.5.2|>=0.7.0|>=0.7.0,<0.8.0|>=0.8.0,<0.9.0']
# ipython -> jedi[version='>=0.16,<1.0'] -> parso[version='0.1.0|>=0.1.0,<0.2|>=0.2.0|>=0.3.0|>=0.5.0|>=0.5.2|>=0.7.0|>=0.7.0,<0.8.0|>=0.8.0,<0.9.0']
#
# Package pycparser conflicts for:
# cryptography -> cffi[version='>=1.12'] -> pycparser
# argon2-cffi -> cffi[version='>=1.0.0'] -> pycparser
# cffi -> pycparser
# brotlipy -> cffi[version='>=1.0.0'] -> pycparser
#
# Package argcomplete conflicts for:
# ipykernel -> argcomplete[version='>=1.12.3']
# notebook -> ipykernel -> argcomplete[version='>=1.12.3']
#
# Package pexpect conflicts for:
# ipython -> pexpect[version='>4.3']
# ipykernel -> ipython[version='>=7.23.1,<8.0'] -> pexpect[version='>4.3']
# jupyterlab -> ipython -> pexpect[version='>4.3']
#
# Package libedit conflicts for:
# sqlite -> libedit[version='>=3.1.20170329,<3.2.0a0|>=3.1.20181209,<3.2.0a0|>=3.1.20191231,<3.2.0a0']
# python=3.9 -> sqlite[version='>=3.33.0,<4.0a0'] -> libedit[version='>=3.1.20191231,<3.2.0a0']
#
# Package python-dateutil conflicts for:
# jupyter_client -> python-dateutil[version='>=2.1']
# matplotlib -> matplotlib-base[version='>=3.4.2,<3.4.3.0a0'] -> python-dateutil[version='>=2.1']
# nbconvert -> jupyter_client[version='>=4.2'] -> python-dateutil[version='>=2.1']
# jupyter_server -> jupyter_client[version='>=6.1.1'] -> python-dateutil[version='>=2.1']
# notebook -> jupyter_client[version='>=5.3.4'] -> python-dateutil[version='>=2.1']
# pandas -> python-dateutil[version='>=2.5.*|>=2.6.1|>=2.7.3']
# ipykernel -> jupyter_client[version='<8.0'] -> python-dateutil[version='>=2.1']
# matplotlib-base -> python-dateutil[version='>=2.1']
# matplotlib -> python-dateutil
# nbclient -> jupyter_client[version='>=6.1.5'] -> python-dateutil[version='>=2.1']
#
# Package mistune conflicts for:
# notebook -> nbconvert -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
# jupyter_server -> nbconvert -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
# nbconvert -> mistune[version='>0.6|>=0.8.1|>=0.8.1,<2']
#
# Package websocket-client conflicts for:
# jupyterlab_server -> jupyter_server[version='>=1.4,<2'] -> websocket-client
# jupyter_server -> websocket-client
# nbclassic -> jupyter_server[version='>=1.0.1,<2.0.0'] -> websocket-client
# jupyterlab -> jupyter_server[version='>=1.4,<2'] -> websocket-client
#
# Package decorator conflicts for:
# ipykernel -> ipython[version='>=7.23.1,<8.0'] -> decorator
# nbclient -> traitlets[version='>=4.2'] -> decorator
# nbconvert -> traitlets[version='>=4.2'] -> decorator
# jupyterlab -> ipython -> decorator
# traitlets -> decorator
# matplotlib-inline -> traitlets -> decorator
# jupyter_core -> traitlets -> decorator
# ipython -> decorator
# jupyter_client -> traitlets -> decorator
# nbformat -> traitlets[version='>=4.1'] -> decorator
# notebook -> traitlets[version='>=4.2.1'] -> decorator
# jupyter_server -> traitlets[version='>=4.2.1'] -> decorator
#
# Package anyio conflicts for:
# jupyterlab -> jupyter_server[version='>=1.4,<2'] -> anyio[version='>=2.0.2|>=3.1.0,<4']
# nbclassic -> jupyter_server[version='>=1.0.1,<2.0.0'] -> anyio[version='>=2.0.2|>=3.1.0,<4']
# jupyterlab_server -> jupyter_server[version='>=1.4,<2'] -> anyio[version='>=2.0.2|>=3.1.0,<4']
# jupyter_server -> anyio[version='>=2.0.2|>=3.1.0,<4']
#
# Package pandocfilters conflicts for:
# jupyter_server -> nbconvert -> pandocfilters[version='>=1.4.1']
# notebook -> nbconvert -> pandocfilters[version='>=1.4.1']
# nbconvert -> pandocfilters[version='>=1.4.1']
#
# Package bleach conflicts for:
# notebook -> nbconvert -> bleach
# nbconvert -> bleach
# jupyter_server -> nbconvert -> bleach
#
# Package contextvars conflicts for:
# anyio -> sniffio[version='>=1.1'] -> contextvars[version='>=2.1']
# sniffio -> contextvars[version='>=2.1']
#
# Package backports conflicts for:
# ipython -> backports.shutil_get_terminal_size -> backports
# wcwidth -> backports.functools_lru_cache -> backports
# matplotlib -> backports.functools_lru_cache -> backports
# tornado -> ssl_match_hostname -> backports
# backports.functools_lru_cache -> backports
# entrypoints -> configparser -> backports
#
# Package lz4-c conflicts for:
# zstd -> lz4-c[version='>=1.9.2,<1.10.0a0|>=1.9.3,<1.10.0a0']
# libtiff -> zstd[version='>=1.4.5,<1.5.0a0'] -> lz4-c[version='>=1.9.2,<1.10.0a0|>=1.9.3,<1.10.0a0']
#
# Package cryptography conflicts for:
# prometheus_client -> twisted -> cryptography[version='>=1.5']
# urllib3 -> pyopenssl[version='>=0.14'] -> cryptography[version='>=1.9|>=2.1.4|>=2.2.1|>=2.8|>=3.2']
# pyopenssl -> cryptography[version='>=1.9|>=2.1.4|>=2.2.1|>=2.8|>=3.2']
# requests -> urllib3[version='>=1.21.1,<1.27'] -> cryptography[version='>=1.3.4']
# urllib3 -> cryptography[version='>=1.3.4']
# requests-unixsocket -> urllib3[version='>=1.8,<2'] -> cryptography[version='>=1.3.4']
#
# Package attrs conflicts for:
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> attrs[version='>=17.4.0']
# prometheus_client -> twisted -> attrs[version='>=17.4.0']
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> attrs[version='>=17.4.0']
# jsonschema -> attrs[version='>=17.4.0']
#
# Package unicodedata2 conflicts for:
# fonttools -> unicodedata2[version='>=13.0.0']
# matplotlib-base -> fonttools[version='>=4.22.0'] -> unicodedata2[version='>=13.0.0']
#
# Package pickleshare conflicts for:
# jupyterlab -> ipython -> pickleshare
# ipykernel -> ipython[version='>=7.23.1,<8.0'] -> pickleshare
# ipython -> pickleshare
#
# Package notebook conflicts for:
# jupyterlab -> nbclassic[version='>=0.2,<1'] -> notebook[version='<7|>=4.2.0']
# jupyterlab_server -> notebook[version='>=4.2.0']
# jupyterlab -> notebook[version='>=4.3|>=4.3.1']
# nbclassic -> notebook[version='<7']
#
# Package requests conflicts for:
# requests-unixsocket -> requests[version='>=1.11,<3']
# jupyterlab_server -> requests
# jupyterlab -> jupyterlab_server[version='>=2.3,<3'] -> requests
# jupyter_server -> requests-unixsocket -> requests[version='>=1.11,<3']
#
# Package subprocess32 conflicts for:
# jupyterlab -> subprocess32
# matplotlib -> subprocess32
#
# Package tbb4py conflicts for:
# mkl_random -> numpy-base[version='>=1.0.2,<2.0a0'] -> tbb4py
# numpy-base -> tbb4py
# mkl_fft -> numpy-base[version='>=1.0.6,<2.0a0'] -> tbb4py
# numpy -> numpy-base==1.15.4=py36h8a80b8c_0 -> tbb4py
#
# Package libwebp-base conflicts for:
# openjpeg -> libtiff[version='>=4.1.0,<5.0a0'] -> libwebp-base
# libtiff -> libwebp-base
# graphviz -> libtiff[version='>=4.0.9,<5.0a0'] -> libwebp-base
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0'] -> libwebp-base
# pillow -> libtiff[version='>=4.1.0,<5.0a0'] -> libwebp-base
#
# Package sniffio conflicts for:
# jupyter_server -> anyio[version='>=2.0.2'] -> sniffio[version='>=1.1']
# anyio -> sniffio[version='>=1.1']
#
# Package libtiff conflicts for:
# graphviz -> libtiff[version='>=4.0.9,<5.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> libtiff[version='>=4.0.10,<5.0a0|>=4.1.0,<5.0a0']
# lcms2 -> libtiff[version='>=4.1.0,<5.0a0']
# openjpeg -> libtiff[version='>=4.0.8,<5.0a0|>=4.0.9,<5.0a0|>=4.1.0,<5.0a0']
# pillow -> libtiff[version='>=4.0.10,<5.0a0|>=4.1.0,<5.0a0|>=4.0.9,<5.0a0|>=4.0.8,<5.0a0']
#
# Package munkres conflicts for:
# fonttools -> munkres
# matplotlib-base -> fonttools[version='>=4.22.0'] -> munkres
#
# Package jupyter_server conflicts for:
# jupyterlab -> jupyterlab_server[version='>=2.3,<3'] -> jupyter_server[version='>=1.0.1,<2.0.0|>=1.1.0,<2.0.0|>=1.8.0,<2.0.0']
# jupyterlab_server -> jupyter_server[version='>=1.1.0,<2.0.0|>=1.4,<2']
# nbclassic -> jupyter_server[version='>=1.0.1,<2.0.0|>=1.8.0,<2.0.0']
# jupyterlab -> jupyter_server[version='>=1.4,<2']
#
# Package defusedxml conflicts for:
# notebook -> nbconvert -> defusedxml
# jupyter_server -> nbconvert -> defusedxml
# nbconvert -> defusedxml
#
# Package twisted conflicts for:
# prometheus_client -> twisted
# notebook -> prometheus_client -> twisted
# jupyter_server -> prometheus_client -> twisted
#
# Package kiwisolver conflicts for:
# matplotlib -> matplotlib-base[version='>=3.4.2,<3.4.3.0a0'] -> kiwisolver[version='>=1.0.1']
# matplotlib-base -> kiwisolver[version='>=1.0.1']
# matplotlib -> kiwisolver
#
# Package jedi conflicts for:
# jupyterlab -> ipython -> jedi[version='>=0.10,<0.18|>=0.16,<1.0']
# ipython -> jedi[version='>=0.10,<0.18|>=0.16,<1.0']
# ipykernel -> ipython[version='>=7.23.1,<8.0'] -> jedi[version='>=0.10,<0.18|>=0.16,<1.0']
#
# Package asn1crypto conflicts for:
# urllib3 -> cryptography[version='>=1.3.4'] -> asn1crypto[version='>=0.21.0']
# cryptography -> asn1crypto[version='>=0.21.0']
# pyopenssl -> cryptography[version='>=2.8'] -> asn1crypto[version='>=0.21.0']
#
# Package webencodings conflicts for:
# bleach -> webencodings
# nbconvert -> bleach -> webencodings
#
# Package babel conflicts for:
# jupyterlab_server -> babel
# jupyterlab -> jupyterlab_server[version='>=2.3,<3'] -> babel
#
# Package html5lib conflicts for:
# nbconvert -> bleach -> html5lib[version='>=0.99999999|>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']
# bleach -> html5lib[version='>=0.99999999|>=0.99999999pre,!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8']
#
# Package fonttools conflicts for:
# matplotlib-base -> fonttools[version='>=4.22.0']
# matplotlib -> matplotlib-base[version='>=3.4.2,<3.4.3.0a0'] -> fonttools[version='>=4.22.0']
#
# Package debugpy conflicts for:
# ipykernel -> debugpy[version='>=1,<2.0']
# notebook -> ipykernel -> debugpy[version='>=1,<2.0']
#
# Package pillow conflicts for:
# matplotlib -> matplotlib-base[version='>=3.4.2,<3.4.3.0a0'] -> pillow[version='>=6.2.0']
# matplotlib-base -> pillow[version='>=6.2.0']
#
# Package jupyterlab_pygments conflicts for:
# jupyter_server -> nbconvert -> jupyterlab_pygments
# notebook -> nbconvert -> jupyterlab_pygments
# nbconvert -> jupyterlab_pygments
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - dl8.5
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - chefboost
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - libsvm
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %% [markdown]
# ## Import some libraries

# %%
## please make sure that the packages are updated to the newest version. 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Getting the data ready

# %% [markdown]
# Load the dataset.

# %%
loans = pd.read_csv('loan_small.csv')

# %% [markdown]
# ### Recoding the target column
#
# We re-assign the target to have +1 as a safe (good) loan, and -1 as a risky (bad) loan. In the next cell, the features are also briefly explained.

# %%
features = ['grade',              # grade of the loan
            'term',               # the term of the loan
            'home_ownership',     # home ownership status: own, mortgage or rent
            'emp_length',         # number of years of employment
           ]

loans['safe_loans'] = loans['loan_status'].apply(lambda x : +1 if x=='Fully Paid' else -1)

## please update pandas to the newest version in order to execute the following line
loans.drop(columns=['loan_status'], inplace=True)

target = 'safe_loans' # this variable will be used later

# %% [markdown]
# ### Transform categorical data into binary features

# %% [markdown]
# In this assignment, we will work with **binary decision trees**. Since all of our features are currently categorical features, we want to turn them into binary features using 1-hot encoding.
#
# We can do so with the following code block:

# %%
loans = pd.get_dummies(loans)

# %% [markdown]
# Let's see what the feature columns look like now:

# %%
features = list(loans.columns)
features.remove('safe_loans')  # Remove the response variable
features
# Out:
# ['term_ 36 months',
#  'term_ 60 months',
#  'grade_A',
#  'grade_B',
#  'grade_C',
#  'grade_D',
#  'grade_E',
#  'grade_F',
#  'grade_G',
#  'home_ownership_MORTGAGE',
#  'home_ownership_NONE',
#  'home_ownership_OTHER',
#  'home_ownership_OWN',
#  'home_ownership_RENT',
#  'emp_length_1 year',
#  'emp_length_10+ years',
#  'emp_length_2 years',
#  'emp_length_3 years',
#  'emp_length_4 years',
#  'emp_length_5 years',
#  'emp_length_6 years',
#  'emp_length_7 years',
#  'emp_length_8 years',
#  'emp_length_9 years',
#  'emp_length_< 1 year']

# %% [markdown]
# ### Train-test split
#
# We split the data into training and test sets with 80% of the data in the training set and 20% of the data in the test set. We use `seed=1` so that everyone gets the same result.

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(loans, test_size = 0.2, random_state=1)

# %% [markdown]
# # Weighted decision trees

# %% [markdown]
# Since the data weights change as we build an AdaBoost model, we need to first code a decision tree that supports weighting of individual data points.

# %% [markdown]
# ### Weighted error definition
#
# Consider a model with $N$ data points with:
# * Predictions $\hat{y}_1 ... \hat{y}_n$
# * Target $y_1 ... y_n$
# * Data point weights $\alpha_1 ... \alpha_n$.
#
# Then the **weighted error** is defined by:
# $$
# \mathrm{E}(\mathbf{\alpha}, \mathbf{\hat{y}}) = \frac{\sum_{i=1}^{n} \alpha_i \times 1[y_i \neq \hat{y_i}]}{\sum_{i=1}^{n} \alpha_i}
# $$
# where $1[y_i \neq \hat{y_i}]$ is an indicator function that is set to $1$ if $y_i \neq \hat{y_i}$.
#
#
# ### Write a function to compute weight of mistakes
#
# Write a function that calculates the weight of mistakes for making the "weighted-majority" predictions for a dataset. The function accepts two inputs:
# * `labels_in_node`: Targets $y_1 ... y_n$
# * `data_weights`: Data point weights $\alpha_1 ... \alpha_n$
#
# We are interested in computing the (total) weight of mistakes, i.e.
# $$
# \mathrm{WM}(\mathbf{\alpha}, \mathbf{\hat{y}}) = \sum_{i=1}^{n} \alpha_i \times 1[y_i \neq \hat{y_i}].
# $$
# This quantity is analogous to the number of mistakes, except that each mistake now carries different weight. It is related to the weighted error in the following way:
# $$
# \mathrm{E}(\mathbf{\alpha}, \mathbf{\hat{y}}) = \frac{\mathrm{WM}(\mathbf{\alpha}, \mathbf{\hat{y}})}{\sum_{i=1}^{n} \alpha_i}
# $$
#
# The function **intermediate_node_weighted_mistakes** should first compute two weights:
#  * $\mathrm{WM}_{-1}$: weight of mistakes when all predictions are $\hat{y}_i = -1$ i.e $\mathrm{WM}(\mathbf{\alpha}, \mathbf{-1}$)
#  * $\mathrm{WM}_{+1}$: weight of mistakes when all predictions are $\hat{y}_i = +1$ i.e $\mbox{WM}(\mathbf{\alpha}, \mathbf{+1}$)
#
#  where $\mathbf{-1}$ and $\mathbf{+1}$ are vectors where all values are -1 and +1 respectively.
#
# After computing $\mathrm{WM}_{-1}$ and $\mathrm{WM}_{+1}$, the function **intermediate_node_weighted_mistakes** should return the lower of the two weights of mistakes, along with the class associated with that weight. We have provided a skeleton for you with `YOUR CODE HERE` to be filled in several places.

# %%
def intermediate_node_weighted_mistakes(labels_in_node, data_weights):
    # Sum the weights of all entries with label +1
    total_weight_positive = sum(data_weights[labels_in_node == +1])
    
    # Weight of mistakes for predicting all -1's is equal to the sum above
    ### YOUR CODE HERE
    WMn = total_weight_positive  
    
    # Sum the weights of all entries with label -1
    ### YOUR CODE HERE
    total_weight_negative = sum(data_weights[labels_in_node == -1])
    
    # Weight of mistakes for predicting all +1's is equal to the sum above
    ### YOUR CODE HERE
    WMp = total_weight_negative
    
    # Return the tuple (weight, class_label) representing the lower of the two weights
    #    class_label should be an integer of value +1 or -1.
    # If the two weights are identical, return (weighted_mistakes_all_positive,+1)
    ### YOUR CODE HERE
    
    return (WMn, -1) if WMn < WMp else (WMp, 1)

# %% [markdown]
# **Checkpoint:** Test your **intermediate_node_weighted_mistakes** function, run the following cell:

# %%
example_labels = pd.Series([-1, -1, 1, 1, 1])
example_data_weights = pd.Series([1., 2., .5, 1., 1.])
if intermediate_node_weighted_mistakes(example_labels, example_data_weights) == (2.5, -1):
    print('Test passed!')
else:
    print('Test failed... try again!')
# Out:
# data weights 0    1.0
# 1    2.0
# 2    0.5
# 3    1.0
# 4    1.0
# dtype: float64
# total_weight_positive 2.5
# WMn 2.5
# total_weight_negative 3.0
# WMp 3.0
# Test passed!

# %% [markdown]
# Recall that the **classification error** is defined as follows:
# $$
# \mbox{classification error} = \frac{\mbox{# mistakes}}{\mbox{# all data points}}
# $$

# %% [markdown]
# ### Function to pick best feature to split on

# %% [markdown]
# The next step is to pick the best feature to split on.
#
# The **best_splitting_feature** function takes the data, the festures, the targetm and the data weights as input and returns the best feature to split on.
#
# Complete the following function.

# %%
# If the data is identical in each feature, this function should return None

def best_splitting_feature(data, features, target, data_weights):
    
    # These variables will keep track of the best feature and the corresponding error
    best_feature = None
    best_error = float('+inf') 
    num_points = float(len(data))

    # Loop through each feature to consider splitting on that feature
    for feature in features:
        
        # The left split will have all data points where the feature value is 0
        # The right split will have all data points where the feature value is 1
        left_split = data[data[feature] == 0]
        right_split = data[data[feature] == 1]
        
        # Apply the same filtering to data_weights to create left_data_weights, right_data_weights
        ## YOUR CODE HERE
        left_data_weights = data_weights[data[feature] == 0]
        right_data_weights = data_weights[data[feature] == 1]
        
        # Calculate the weight of mistakes for left and right sides
        ## YOUR CODE HERE        
        left_mistakes_weight = sum(left_data_weights[feature == -1])
        right_mistakes_weight = sum(right_data_weights[feature == +1])
                    
        # Compute weighted error by computing
        #  ( [weight of mistakes (left)] + [weight of mistakes (right)] ) / [total weight of all data points]
        ## YOUR CODE HERE
        error = ( left_mistakes_weight + right_mistakes_weight ) / sum(data_weights)
        
        # If this is the best error we have found so far, store the feature and the error
        if error < best_error:
            best_feature = feature
            best_error = error
    
    # Return the best feature we found
    return best_feature

# %% [markdown]
# **Checkpoint:** Now, we have another checkpoint to make sure you are on the right track.

# %%
example_data_weights = np.array(len(train_data)* [1.5])
if best_splitting_feature(train_data, features, target, example_data_weights) == 'term_ 36 months':
    print('Test passed!')
else:
    print('Test failed... try again!')
# Out:
# Test passed!

# %% [markdown]
# **Aside**. Relationship between weighted error and weight of mistakes:
#
# By definition, the weighted error is the weight of mistakes divided by the weight of all data points, so
# $$
# \mathrm{E}(\mathbf{\alpha}, \mathbf{\hat{y}}) = \frac{\sum_{i=1}^{n} \alpha_i \times 1[y_i \neq \hat{y_i}]}{\sum_{i=1}^{n} \alpha_i} = \frac{\mathrm{WM}(\mathbf{\alpha}, \mathbf{\hat{y}})}{\sum_{i=1}^{n} \alpha_i}.
# $$
#
# In the code above, we obtain $\mathrm{E}(\mathbf{\alpha}, \mathbf{\hat{y}})$ from the two weights of mistakes from both sides, $\mathrm{WM}(\mathbf{\alpha}_{\mathrm{left}}, \mathbf{\hat{y}}_{\mathrm{left}})$ and $\mathrm{WM}(\mathbf{\alpha}_{\mathrm{right}}, \mathbf{\hat{y}}_{\mathrm{right}})$. First, notice that the overall weight of mistakes $\mathrm{WM}(\mathbf{\alpha}, \mathbf{\hat{y}})$ can be broken into two weights of mistakes over either side of the split:
# $$
# \mathrm{WM}(\mathbf{\alpha}, \mathbf{\hat{y}})
# = \sum_{i=1}^{n} \alpha_i \times 1[y_i \neq \hat{y_i}]
# = \sum_{\mathrm{left}} \alpha_i \times 1[y_i \neq \hat{y_i}] + \sum_{\mathrm{right}} \alpha_i \times 1[y_i \neq \hat{y_i}]\\
# = \mathrm{WM}(\mathbf{\alpha}_{\mathrm{left}}, \mathbf{\hat{y}}_{\mathrm{left}}) + \mathrm{WM}(\mathbf{\alpha}_{\mathrm{right}}, \mathbf{\hat{y}}_{\mathrm{right}})
# $$
# We then divide through by the total weight of all data points to obtain $\mathrm{E}({\alpha}, \mathbf{\hat{y}})$:
# $$
# \mathrm{E}({\alpha}, \mathbf{\hat{y}})
# = \frac{\mathrm{WM}({\alpha}_{\mathrm{left}}, \mathbf{\hat{y}}_{\mathrm{left}}) + \mathrm{WM}({\alpha}_{\mathrm{right}}, \mathbf{\hat{y}}_{\mathrm{right}})}{\sum_{i=1}^{n} \alpha_i}
# $$

# %% [markdown]
# ### Building the tree
#
# With the above functions implemented correctly, we are now ready to build our decision tree. A decision tree will be represented as a dictionary which contains the following keys:
#
#     {
#        'is_leaf'            : True/False.
#        'prediction'         : Prediction at the leaf node.
#        'left'               : (dictionary corresponding to the left tree).
#        'right'              : (dictionary corresponding to the right tree).
#        'features_remaining' : List of features that are posible splits.
#     }
#
# Let us start with a function that creates a leaf node given a set of target values:

# %%
def create_leaf(target_values, data_weights):
    
    # Create a leaf node
    leaf = {'splitting_feature' : None,
            'is_leaf': True}
    
    # Computed weight of mistakes.
    weighted_error, best_class = intermediate_node_weighted_mistakes(target_values, data_weights)
    # Store the predicted class (1 or -1) in leaf['prediction']
    ## YOUR CODE HERE
    leaf['prediction'] = best_class
    
    return leaf

# %% [markdown]
# We provide a function that learns a weighted decision tree recursively and implements 3 stopping conditions:
# 1. All data points in a node are from the same class.
# 2. No more features to split on.
# 3. Stop growing the tree when the tree depth reaches **max_depth**.

# %%
def weighted_decision_tree_create(data, features, target, data_weights, current_depth = 1, max_depth = 10):
    remaining_features = features[:] # Make a copy of the features.
    print("target",target)
    target_values = data[target]
    print("--------------------------------------------------------------------")
    print("Subtree, depth = %s (%s data points)." % (current_depth, len(target_values)))
#     print("target_values",target_values)
    
    # Stopping condition 1. Error is 0.
    if intermediate_node_weighted_mistakes(target_values, data_weights)[0] <= 1e-15:
        print("Stopping condition 1 reached.")                
        return create_leaf(target_values, data_weights)
    
    # Stopping condition 2. No more features.
    if remaining_features == []:
        print("Stopping condition 2 reached.")                
        return create_leaf(target_values, data_weights)    
    
    # Additional stopping condition (limit tree depth)
    if current_depth > max_depth:
        print("Reached maximum depth. Stopping for now.")
        return create_leaf(target_values, data_weights)
    
    # If all the datapoints are the same, splitting_feature will be None. Create a leaf
    splitting_feature = best_splitting_feature(data, features, target, data_weights)
    remaining_features.remove(splitting_feature)
        
    left_split = data[data[splitting_feature] == 0]
    right_split = data[data[splitting_feature] == 1]
    
    left_data_weights = data_weights[data[splitting_feature] == 0]
    right_data_weights = data_weights[data[splitting_feature] == 1]
    
    print("Split on feature %s. (%s, %s)" % (\
              splitting_feature, len(left_split), len(right_split)))
    
    # Create a leaf node if the split is "perfect"
    if len(left_split) == len(data):
        print("Creating leaf node.")
        return create_leaf(left_split[target], data_weights)
    if len(right_split) == len(data):
        print("Creating leaf node.")
        return create_leaf(right_split[target], data_weights)
    
    # Repeat (recurse) on left and right subtrees
    ## YOUR CODE HERE
    left_tree = weighted_decision_tree_create(data, remaining_features, target,
                                              data_weights, current_depth+1, max_depth)
    right_tree = weighted_decision_tree_create(data, remaining_features, target,
                                               data_weights, current_depth+1, max_depth)
    
    return {'is_leaf'          : False, 
            'prediction'       : None,
            'splitting_feature': splitting_feature,
            'left'             : left_tree, 
            'right'            : right_tree}

# %% [markdown]
# Here is a recursive function to count the nodes in your tree:

# %%
def count_nodes(tree):
    if tree['is_leaf']:
        return 1
    return 1 + count_nodes(tree['left']) + count_nodes(tree['right'])

# %% [markdown]
# Run the following test code to check your implementation. Make sure you get **'Test passed'** before proceeding.

# %%
example_data_weights = np.array([1.0 for i in range(len(train_data))])
print(target)
small_data_decision_tree = weighted_decision_tree_create(train_data, features, target,
                                        example_data_weights, max_depth=2)
if count_nodes(small_data_decision_tree) == 7:
    print('Test passed!')
else:
    print('Test failed... try again!')
    print('Number of nodes found:', count_nodes(small_data_decision_tree))
    print('Number of nodes that should be there: 7')
# Out:
# safe_loans
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 1 (32000 data points).
# Split on feature term_ 36 months. (8850, 23150)
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Split on feature term_ 60 months. (23150, 8850)
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 3 (32000 data points).
# Reached maximum depth. Stopping for now.
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 3 (32000 data points).
# Reached maximum depth. Stopping for now.
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Split on feature term_ 60 months. (23150, 8850)
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 3 (32000 data points).
# Reached maximum depth. Stopping for now.
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 3 (32000 data points).
# Reached maximum depth. Stopping for now.
# Test passed!

# %% [markdown]
# Let us take a quick look at what the trained tree is like. You should get something that looks like the following
#
# ```
# {'is_leaf': False,
#     'left': {'is_leaf': False,
#         'left': {'is_leaf': True, 'prediction': -1, 'splitting_feature': None},
#         'prediction': None,
#         'right': {'is_leaf': True, 'prediction': 1, 'splitting_feature': None},
#         'splitting_feature': 'grade_A'
#      },
#     'prediction': None,
#     'right': {'is_leaf': False,
#         'left': {'is_leaf': True, 'prediction': 1, 'splitting_feature': None},
#         'prediction': None,
#         'right': {'is_leaf': True, 'prediction': -1, 'splitting_feature': None},
#         'splitting_feature': 'grade_D'
#      },
#      'splitting_feature': 'term. 36 months'
# }```

# %%
small_data_decision_tree
# Out:
# {'is_leaf': False,
#  'prediction': None,
#  'splitting_feature': 'term_ 36 months',
#  'left': {'is_leaf': False,
#   'prediction': None,
#   'splitting_feature': 'term_ 60 months',
#   'left': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1},
#   'right': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}},
#  'right': {'is_leaf': False,
#   'prediction': None,
#   'splitting_feature': 'term_ 60 months',
#   'left': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1},
#   'right': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}}}

# %% [markdown]
# ### Making predictions with a weighted decision tree

# %% [markdown]
# We give you a function that classifies one data point. It can also return the probability if you want to play around with that as well.

# %%
def classify(tree, x, annotate = False):   
    # If the node is a leaf node.
    if tree['is_leaf']:
        if annotate: 
            print("At leaf, predicting %s" % tree['prediction'])
        return tree['prediction'] 
    else:
        # Split on feature.
        split_feature_value = x[tree['splitting_feature']]
        if annotate: 
            print("Split on %s = %s" % (tree['splitting_feature'], split_feature_value))
        if split_feature_value == 0:
            return classify(tree['left'], x, annotate)
        else:
            return classify(tree['right'], x, annotate)

# %% [markdown]
# ### Evaluating the tree
#
# Now, we will write a function to evaluate a decision tree by computing the classification error of the tree on the given dataset.
#
# Again, recall that the **classification error** is defined as follows:
# $$
# \mbox{classification error} = \frac{\mbox{# mistakes}}{\mbox{# all data points}}
# $$
#
# The function called **evaluate_classification_error** takes in as input:
# 1. `tree` (as described above)
# 2. `data` (a dataframe)
#
# The function does not change because of adding data point weights.

# %%
def evaluate_classification_error(tree, data):
    # Apply the classify(tree, x) to each row in your data
    # YOUR CODE HERE
    prediction = data.apply(lambda row: classify(tree, row), axis=1)
    
    # Once you've made the predictions, calculate the classification error
    return (prediction != data[target]).sum() / float(len(data))

# %%
evaluate_classification_error(small_data_decision_tree, test_data)
# Out:
# 0.504125

# %% [markdown]
# ### Example: Training a weighted decision tree
#
# To build intuition on how weighted data points affect the tree being built, consider the following:
#
# Suppose we only care about making good predictions for the **first 10 and last 10 items** in `train_data`, we assign weights:
# * 1 to the last 10 items
# * 1 to the first 10 items
# * and 0 to the rest.
#
# Let us fit a weighted decision tree with `max_depth = 2`.

# %%
# Assign weights
example_data_weights = np.array([1.] * 10 + [0.]*(len(train_data) - 20) + [1.] * 10)

# Train a weighted decision tree model.
small_data_decision_tree_subset_20 = weighted_decision_tree_create(train_data, features, target,
                         example_data_weights, max_depth=2)
# Out:
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 1 (32000 data points).
# Split on feature term_ 36 months. (8850, 23150)
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Split on feature term_ 60 months. (23150, 8850)
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 3 (32000 data points).
# Reached maximum depth. Stopping for now.
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 3 (32000 data points).
# Reached maximum depth. Stopping for now.
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Split on feature term_ 60 months. (23150, 8850)
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 3 (32000 data points).
# Reached maximum depth. Stopping for now.
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 3 (32000 data points).
# Reached maximum depth. Stopping for now.

# %% [markdown]
# Now, we will compute the classification error on the `subset_20`, i.e. the subset of data points whose weight is 1 (namely the first and last 10 data points).

# %%
subset_20 = train_data.head(10).append(train_data.tail(10))
evaluate_classification_error(small_data_decision_tree_subset_20, subset_20)
# Out:
# 0.4

# %% [markdown]
# Now, let us compare the classification error of the model `small_data_decision_tree_subset_20` on the entire test set `train_data`:

# %%
evaluate_classification_error(small_data_decision_tree_subset_20, train_data)
# Out:
# 0.49896875

# %% [markdown]
# The model `small_data_decision_tree_subset_20` performs **a lot** better on `subset_20` than on `train_data`.
#
# So, what does this mean?
# * The points with higher weights are the ones that are more important during the training process of the weighted decision tree.
# * The points with zero weights are basically ignored during training.

# %% [markdown]
# # Implementing your own Adaboost (on decision stumps)

# %% [markdown]
# Now that we have a weighted decision tree working, it takes only a bit of work to implement Adaboost. For the sake of simplicity, let us stick with **decision tree stumps** by training trees with **`max_depth=1`**.

# %% [markdown]
# Recall from the lecture notes the procedure for Adaboost:
#
# 1\. Start with unweighted data with $\alpha_j = 1$
#
# 2\. For t = 1,...T:
#   * Learn $f_t(x)$ with data weights $\alpha_j$
#   * Compute coefficient $\hat{w}_t$:
#      $$\hat{w}_t = \frac{1}{2}\ln{\left(\frac{1- \mbox{E}(\mathbf{\alpha}, \mathbf{\hat{y}})}{\mbox{E}(\mathbf{\alpha}, \mathbf{\hat{y}})}\right)}$$
#   * Re-compute weights $\alpha_j$:
#      $$\alpha_j \gets \begin{cases}
#      \alpha_j \exp{(-\hat{w}_t)} & \text{ if }f_t(x_j) = y_j\\
#      \alpha_j \exp{(\hat{w}_t)} & \text{ if }f_t(x_j) \neq y_j
#      \end{cases}$$
#   * Normalize weights $\alpha_j$:
#       $$\alpha_j \gets \frac{\alpha_j}{\sum_{i=1}^{N}{\alpha_i}} $$
#
# Complete the skeleton for the following code to implement **adaboost_with_tree_stumps**. Fill in the places with `YOUR CODE HERE`.

# %%
from math import log
from math import exp


def adaboost_with_tree_stumps(data, features, target, num_tree_stumps):
    # start with unweighted data (uniformly weighted)
    alpha =  np.array([1]*len(data))
    tree_stumps = []
    stump_weights = []
    target_values = data[target]
    
    for t in range(num_tree_stumps):
        print('=====================================================')
        print('Adaboost Iteration %d' % t)
        print('=====================================================')        
        # Learn a weighted decision tree stump. Use max_depth=1
        # YOUR CODE HERE
        print("len(alpha)", len(alpha))
        decision_tree_stump = weighted_decision_tree_create(data, features, target,
                                        alpha, max_depth=1)
        tree_stumps.append(decision_tree_stump)
        print("decision_tree_stump", decision_tree_stump)
        
        # Make predictions
        ## YOUR CODE HERE
        predictions = data.apply(lambda row: classify(decision_tree_stump, row), axis=1)
        print("len(predicitons)", len(predictions))
        
        # Produce a Boolean array indicating whether
        # each data point was correctly classified
        is_correct = predictions == target_values
        is_wrong   = predictions != target_values
        
        # Compute weighted error
        ## YOUR CODE HERE
        WM = sum(alpha[i] if row else 0 for i,row in is_wrong.iteritems())
        print("WM", WM)
        print("sum(alpha)",sum(alpha))
        E = WM/sum(alpha)
        print("E", E)
        
        # Compute model coefficient using weighted error
        ## YOUR CODE HERE
        wt = 0.5 * log( (1-E) / E ) #if (1-E) !=0 else None
        stump_weights.append(wt)
        print("wt:", wt)
        
        # Adjust weights on data point
        ## YOUR CODE HERE
        adjustment = is_correct.apply(lambda is_correct : exp(-wt) if is_correct else exp(wt))
        
        # Scale alpha by multiplying by adjustment 
        # Then normalize data points weights
        ## YOUR CODE HERE 
        alpha_new = alpha*adjustment.to_numpy()
        print("alpha_new", alpha_new)
        alpha=alpha_new/sum(alpha_new)
        print("alpha", alpha)
        print("sum(alpha)", sum(alpha))
        
    print("tree_stumps", tree_stumps)
    return stump_weights, tree_stumps

# %% [markdown]
# ### Checking your Adaboost code
#
# Train an ensemble of **two** tree stumps and see which features those stumps split on. We will run the algorithm with the following parameters:
# * `train_data`
# * `features`
# * `target`
# * `num_tree_stumps = 2`

# %%
stump_weights, tree_stumps = adaboost_with_tree_stumps(train_data, features, target, num_tree_stumps=2)
# Out:
# =====================================================
# Adaboost Iteration 0
# =====================================================
# len(alpha) 32000
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 1 (32000 data points).
# Split on feature term_ 36 months. (8850, 23150)
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Reached maximum depth. Stopping for now.
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Reached maximum depth. Stopping for now.
# decision_tree_stump {'is_leaf': False, 'prediction': None, 'splitting_feature': 'term_ 36 months', 'left': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}, 'right': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}}
# len(predicitons) 32000
# WM 15967
# sum(alpha) 32000
# E 0.49896875
# wt: 0.0020625029245680804
# alpha_new [0.99793962 1.00206463 0.99793962 ... 1.00206463 1.00206463 0.99793962]
# alpha [3.11856795e-05 3.13145863e-05 3.11856795e-05 ... 3.13145863e-05
#  3.13145863e-05 3.11856795e-05]
# sum(alpha) 1.0000000000003413
# =====================================================
# Adaboost Iteration 1
# =====================================================
# len(alpha) 32000
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 1 (32000 data points).
# Split on feature term_ 36 months. (8850, 23150)
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Reached maximum depth. Stopping for now.
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Reached maximum depth. Stopping for now.
# decision_tree_stump {'is_leaf': False, 'prediction': None, 'splitting_feature': 'term_ 36 months', 'left': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}, 'right': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}}
# len(predicitons) 32000
# WM 0.4989745464192516
# sum(alpha) 1.0000000000003413
# E 0.4989745464190813
# wt: 0.00205091003736703
# alpha_new [3.11217861e-05 3.13788756e-05 3.11217861e-05 ... 3.13788756e-05
#  3.13788756e-05 3.11217861e-05]
# alpha [3.11217206e-05 3.13788096e-05 3.11217206e-05 ... 3.13788096e-05
#  3.13788096e-05 3.11217206e-05]
# sum(alpha) 0.9999999999999101
# tree_stumps [{'is_leaf': False, 'prediction': None, 'splitting_feature': 'term_ 36 months', 'left': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}, 'right': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}}, {'is_leaf': False, 'prediction': None, 'splitting_feature': 'term_ 36 months', 'left': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}, 'right': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}}]

# %%
def print_stump(tree):
    split_name = tree['splitting_feature'] # split_name is something like 'term. 36 months'
    if split_name is None:
        print("(leaf, label: %s)" % tree['prediction'])
        return None
    split_feature, split_value = split_name.split('_')
    print('                       root')
    print('         |---------------|----------------|')
    print('         |                                |')
    print('         |                                |')
    print('         |                                |')
    print('  [{0} == 0]{1}[{0} == 1]    '.format(split_name, ' '*(27-len(split_name))))
    print('         |                                |')
    print('         |                                |')
    print('         |                                |')
    print('    (%s)                 (%s)' \
        % (('leaf, label: ' + str(tree['left']['prediction']) if tree['left']['is_leaf'] else 'subtree'),
           ('leaf, label: ' + str(tree['right']['prediction']) if tree['right']['is_leaf'] else 'subtree')))

# %% [markdown]
# Here is what the first stump looks like:

# %%
print_stump(tree_stumps[0])
# Out:
#                        root
#          |---------------|----------------|
#          |                                |
#          |                                |
#          |                                |
#   [term_ 36 months == 0]            [term_ 36 months == 1]
#          |                                |
#          |                                |
#          |                                |
#     (leaf, label: -1)                 (leaf, label: -1)

# %% [markdown]
# Here is what the next stump looks like:

# %%
print_stump(tree_stumps[1])
# Out:
#                        root
#          |---------------|----------------|
#          |                                |
#          |                                |
#          |                                |
#   [term_ 36 months == 0]            [term_ 36 months == 1]
#          |                                |
#          |                                |
#          |                                |
#     (leaf, label: -1)                 (leaf, label: -1)

# %%
print(stump_weights)
# Out:
# [0.0020625029245680804, 0.00205091003736703]

# %% [markdown]
# If your Adaboost is correctly implemented, the following things should be true:
#
# * `tree_stumps[0]` should split on **term. 36 months** with the prediction -1 on the left and +1 on the right.
# * `tree_stumps[1]` should split on **grade.A** with the prediction -1 on the left and +1 on the right.
# * Weights should be approximately `[0.17, 0.18]`
#
# **Reminders**
# - Stump weights ($\mathbf{\hat{w}}$) and data point weights ($\mathbf{\alpha}$) are two different concepts.
# - Stump weights ($\mathbf{\hat{w}}$) tell you how important each stump is while making predictions with the entire boosted ensemble.
# - Data point weights ($\mathbf{\alpha}$) tell you how important each data point is while training a decision stump.

# %% [markdown]
# ### Training a boosted ensemble of 10 stumps

# %% [markdown]
# Let us train an ensemble of 10 decision tree stumps with Adaboost. We run the **adaboost_with_tree_stumps** function with the following parameters:
# * `train_data`
# * `features`
# * `target`
# * `num_tree_stumps = 10`

# %%
stump_weights, tree_stumps = adaboost_with_tree_stumps(train_data, features, 
                                target, num_tree_stumps=10)
# Out:
# =====================================================
# Adaboost Iteration 0
# =====================================================
# len(alpha) 32000
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 1 (32000 data points).
# Split on feature term_ 36 months. (8850, 23150)
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Reached maximum depth. Stopping for now.
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Reached maximum depth. Stopping for now.
# decision_tree_stump {'is_leaf': False, 'prediction': None, 'splitting_feature': 'term_ 36 months', 'left': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}, 'right': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}}
# len(predicitons) 32000
# WM 15967
# sum(alpha) 32000
# E 0.49896875
# wt: 0.0020625029245680804
# alpha_new [0.99793962 1.00206463 0.99793962 ... 1.00206463 1.00206463 0.99793962]
# alpha [3.11856795e-05 3.13145863e-05 3.11856795e-05 ... 3.13145863e-05
#  3.13145863e-05 3.11856795e-05]
# sum(alpha) 1.0000000000003413
# =====================================================
# Adaboost Iteration 1
# =====================================================
# len(alpha) 32000
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 1 (32000 data points).
# Split on feature term_ 36 months. (8850, 23150)
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Reached maximum depth. Stopping for now.
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Reached maximum depth. Stopping for now.
# decision_tree_stump {'is_leaf': False, 'prediction': None, 'splitting_feature': 'term_ 36 months', 'left': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}, 'right': {'splitting_feature': None, 'is_leaf': True, 'prediction': -1}}
# len(predicitons) 32000
# WM 0.4989745464192516
# sum(alpha) 1.0000000000003413
# E 0.4989745464190813
# wt: 0.00205091003736703
# alpha_new [3.11217861e-05 3.13788756e-05 3.11217861e-05 ... 3.13788756e-05
#  3.13788756e-05 3.11217861e-05]
# alpha [3.11217206e-05 3.13788096e-05 3.11217206e-05 ... 3.13788096e-05
#  3.13788096e-05 3.11217206e-05]
# sum(alpha) 0.9999999999999101
# =====================================================
# Adaboost Iteration 2
# =====================================================
# len(alpha) 32000
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 1 (32000 data points).
# Split on feature term_ 36 months. (8850, 23150)
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Reached maximum depth. Stopping for now.
# target safe_loans
# --------------------------------------------------------------------
# Subtree, depth = 2 (32000 data points).
# Reached maximum depth. Stopping for now.
# decision_tree_stump {'is_leaf': False, 'prediction': None, 'splitting_feature': 'term_ 36 months', 'left': {'splitting_feature': None, 'is_leaf': True, 'prediction': 1}, 'right': {'splitting_feature': None, 'is_leaf': True, 'prediction': 1}}
# len(predicitons) 32000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/k8/wy10l4qx29x7j42dzjtj5zbh0000gn/T/ipykernel_13064/2134935491.py in <module>
# ----> 1 stump_weights, tree_stumps = adaboost_with_tree_stumps(train_data, features,
#       2                                 target, num_tree_stumps=10)
#
# /var/folders/k8/wy10l4qx29x7j42dzjtj5zbh0000gn/T/ipykernel_13064/4245054541.py in adaboost_with_tree_stumps(data, features, target, num_tree_stumps)
#      34         # Compute weighted error
#      35         ## YOUR CODE HERE
# ---> 36         WM = sum(alpha[i] if row else 0 for i,row in is_wrong.iteritems())
#      37         print("WM", WM)
#      38         print("sum(alpha)",sum(alpha))
#
# /var/folders/k8/wy10l4qx29x7j42dzjtj5zbh0000gn/T/ipykernel_13064/4245054541.py in <genexpr>(.0)
#      34         # Compute weighted error
#      35         ## YOUR CODE HERE
# ---> 36         WM = sum(alpha[i] if row else 0 for i,row in is_wrong.iteritems())
#      37         print("WM", WM)
#      38         print("sum(alpha)",sum(alpha))
#
# IndexError: index 36677 is out of bounds for axis 0 with size 32000

# %% [markdown]
# ### Plot the boosted stumps in the additive model
#
# The decision stumps picks a feature and a threshold, visualize them here.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Making predictions
#
# Recall from the lecture that in order to make predictions, we use the following formula:
# $$
# \hat{y} = sign\left(\sum_{t=1}^T \hat{w}_t f_t(x)\right)
# $$
#
# We need to do the following things:
# - Compute the predictions $f_t(x)$ using the $t$-th decision tree
# - Compute $\hat{w}_t f_t(x)$ by multiplying the `stump_weights` with the predictions $f_t(x)$ from the decision trees
# - Sum the weighted predictions over each stump in the ensemble.
#
# Complete the following skeleton for making predictions:

# %%
def predict_adaboost(stump_weights, tree_stumps, data):
    scores = np.array([0.]*len(data))
    
    for i, tree_stump in enumerate(tree_stumps):
        predictions = data.apply(lambda x: classify(tree_stump, x), axis = 1)
        
        # Accumulate predictions on scaores array
        # YOUR CODE HERE
        ...
        
    return scores.apply(lambda score : +1 if score > 0 else -1)

# %%
predictions = predict_adaboost(stump_weights, tree_stumps, test_data)

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(test_data[target], predictions)
print('Accuracy of 10-component ensemble = %s' % accuracy)

# %% [markdown]
# Now, let us take a quick look what the `stump_weights` look like at the end of each iteration of the 10-stump ensemble:

# %%
stump_weights

# %% [markdown]
# **Question** i: Are the weights monotonically decreasing, monotonically increasing, or neither?
#
# **Reminder**: Stump weights ($\mathbf{\hat{w}}$) tell you how important each stump is while making predictions with the entire boosted ensemble.

# %% [markdown]
# # Performance plots
#
# In this section, we will try to reproduce some performance plots.
#
# ### How does accuracy change with adding stumps to the ensemble?
#
# We will now train an ensemble with:
# * `train_data`
# * `features`
# * `target`
# * `num_tree_stumps = 30`
#
# Once we are done with this, we will then do the following:
# * Compute the classification error at the end of each iteration.
# * Plot a curve of classification error vs iteration.
#
# First, lets train the model.

# %%
# this may take a while... 
stump_weights, tree_stumps = adaboost_with_tree_stumps(train_data, 
                                 features, target, num_tree_stumps=30)

# %% [markdown]
# ### Computing training error at the end of each iteration
#
# Now, we will compute the classification error on the **train_data** and see how it is reduced as trees are added.

# %%
error_all = []
for n in range(1, 31):
    predictions = predict_adaboost(stump_weights[:n], tree_stumps[:n], train_data)
    error = 1.0 - accuracy_score(train_data[target], predictions)
    error_all.append(error)
    print("Iteration %s, training error = %s" % (n, error_all[n-1]))

# %% [markdown]
# ### Visualizing training error vs number of iterations
#
# We have provided you with a simple code snippet that plots classification error with the number of iterations.

# %%
plt.rcParams['figure.figsize'] = 7, 5
plt.plot(list(range(1,31)), error_all, '-', linewidth=4.0, label='Training error')
plt.title('Performance of Adaboost ensemble')
plt.xlabel('# of iterations')
plt.ylabel('Classification error')
plt.legend(loc='best', prop={'size':15})

plt.rcParams.update({'font.size': 16})

# %% [markdown]
# ### Evaluation on the test data
#
# Performing well on the training data is cheating, so lets make sure it works on the `test_data` as well. Here, we will compute the classification error on the `test_data` at the end of each iteration.

# %%
test_error_all = []
for n in range(1, 31):
    predictions = predict_adaboost(stump_weights[:n], tree_stumps[:n], test_data)
    error = 1.0 - accuracy_score(test_data[target], predictions)
    test_error_all.append(error)
    print("Iteration %s, test error = %s" % (n, test_error_all[n-1]))

# %% [markdown]
# ### Visualize both the training and test errors
#
# Now, let us plot the training & test error with the number of iterations.

# %%
plt.rcParams['figure.figsize'] = 7, 5
plt.plot(list(range(1,31)), error_all, '-', linewidth=4.0, label='Training error')
plt.plot(list(range(1,31)), test_error_all, '-', linewidth=4.0, label='Test error')

plt.title('Performance of Adaboost ensemble')
plt.xlabel('# of iterations')
plt.ylabel('Classification error')
plt.rcParams.update({'font.size': 16})
plt.legend(loc='best', prop={'size':15})
plt.tight_layout()

# %% [markdown]
# **Question** ii: From this plot (with 30 trees), is there massive overfitting as the # of iterations increases?
